# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv"
# Out:
# zsh:1: command not found: gdown

# %%
aero=pd.read_csv("aerofit_treadmill.csv")

# %%
aero
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
aero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
aero.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
aero.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47
# 5   KP281   20  Female         14     Partnered      3        3   32973     66
# 6   KP281   21  Female         14     Partnered      3        3   35247     75
# 7   KP281   21    Male         13        Single      3        3   32973     85
# 8   KP281   21    Male         15        Single      5        4   35247    141
# 9   KP281   21  Female         15     Partnered      2        3   37521     85

# %%
aero.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   KP781   31    Male         16     Partnered      6        5   89641
# 171   KP781   33  Female         18     Partnered      4        5   95866
# 172   KP781   34    Male         16        Single      5        5   92131
# 173   KP781   35    Male         16     Partnered      4        5   92131
# 174   KP781   38    Male         18     Partnered      5        5  104581
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
aero.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
aero.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
aero.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
aero.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(f"Number of rows: {aero.shape[0]}\nNumber of columns: {aero.shape[1]}")
# Out:
# Number of rows: 180
# Number of columns: 9

# %% [markdown]
# Observations:
# 1.There are no missing values in the data.
# 2.There are 3 unique products in the dataset.
# 3.KP281 is the most frequent product.
# 4.Minimum & Maximum age of the person is 18 & 50, mean is 28.79 and 75% of persons have age less than or equal to 33.
# Most of the people are having 16 years of education i.e. 75% of persons are having education <= 16 years.
# 5.Out of 180 data points, 104's gender is Male and rest are the female.
# 6.Standard deviation for Income & Miles is very high. These variables might have the outliers in it.

# %%
fig, axis = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))
fig.subplots_adjust(top=1.2)

sns.histplot(data=aero, x="Age", kde=True, ax=axis[0,0])
sns.histplot(data=aero, x="Education", kde=True, ax=axis[0,1])
sns.histplot(data=aero, x="Usage", kde=True, ax=axis[0,2])
sns.histplot(data=aero, x="Fitness", kde=True, ax=axis[1,0])
sns.histplot(data=aero, x="Income", kde=True, ax=axis[1,1])
sns.histplot(data=aero, x="Miles", kde=True, ax=axis[1,2])
plt.show()

# %%
fig, axis = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))
fig.subplots_adjust(top=1.2)

sns.boxplot(data=aero, x="Age", orient='h', ax=axis[0,0])
sns.boxplot(data=aero, x="Education", orient='h', ax=axis[0,1])
sns.boxplot(data=aero, x="Usage", orient='h', ax=axis[0,2])
sns.boxplot(data=aero, x="Fitness", orient='h', ax=axis[1,0])
sns.boxplot(data=aero, x="Income", orient='h', ax=axis[1,1])
sns.boxplot(data=aero, x="Miles", orient='h', ax=axis[1,2])
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))
sns.countplot(data=aero, x='Product', ax=axs[0])
sns.countplot(data=aero, x='Gender', ax=axs[1])
sns.countplot(data=aero, x='MaritalStatus', ax=axs[2])
axs[0].set_title("Product - counts", pad=10, fontsize=14)
axs[1].set_title("Gender - counts", pad=10, fontsize=14)
axs[2].set_title("MaritalStatus - counts", pad=10, fontsize=14)
# Out:
# Text(0.5, 1.0, 'MaritalStatus - counts')

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Checking if features - Gender or MaritalStatus have any effect on the product purchased.¶

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 6.5))
sns.countplot(data=aero, x='Product', hue='Gender', ax=axs[0])
sns.countplot(data=aero, x='Product', hue='MaritalStatus', ax=axs[1])
axs[0].set_title("Product VS Gender ", pad=10, fontsize=14)
axs[1].set_title("Product VS MaritalStatus ", pad=10, fontsize=14)
# Out:
# Text(0.5, 1.0, 'Product VS MaritalStatus ')

# %% [markdown]
# Checking diffrent how diffrent coloums - situation  have any effect against product :
# 1.Age
# 2.Education
# 3.Usage
# 4.Fitness
# 5.Income
# 6.Miles

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))
sns.boxplot(data=aero, x='Product', y='Age', ax=axs[0,0],palette='Set3')
sns.boxplot(data=aero, x='Product', y='Education', ax=axs[0,1], palette='Set2')
sns.boxplot(data=aero, x='Product', y='Usage', ax=axs[0,2], palette='Set1')
sns.boxplot(data=aero, x='Product', y='Fitness', ax=axs[1,0], palette='Set3')
sns.boxplot(data=aero, x='Product', y='Income', ax=axs[1,1], palette='Set2')
sns.boxplot(data=aero, x='Product', y='Miles', ax=axs[1,2], palette='Set1')
axs[0,0].set_title("Product VS Age ", pad=10, fontsize=14)
axs[0,1].set_title("Product VS Education ", pad=10, fontsize=14)
axs[0,2].set_title("Product VS Usage ", pad=10, fontsize=14)
axs[1,0].set_title("Product VS Fitness ", pad=10, fontsize=14)
axs[1,1].set_title("Product VS Income ", pad=10, fontsize=14)
axs[1,2].set_title("Product VS Miles ", pad=10, fontsize=14)
# Out:
# /var/folders/q4/r82zndsd4y35n76xr9d24qh00000gn/T/ipykernel_12157/1978179970.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=aero, x='Product', y='Age', ax=axs[0,0],palette='Set3')
# /var/folders/q4/r82zndsd4y35n76xr9d24qh00000gn/T/ipykernel_12157/1978179970.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=aero, x='Product', y='Education', ax=axs[0,1], palette='Set2')
# /var/folders/q4/r82zndsd4y35n76xr9d24qh00000gn/T/ipykernel_12157/1978179970.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Multivariate analysis

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))
sns.boxplot(data=aero, x='Gender', y='Age', hue='Product', ax=axs[0,0], palette='Set1')
sns.boxplot(data=aero, x='Gender', y='Education', hue='Product', ax=axs[0,1], palette='Set2')
sns.boxplot(data=aero, x='Gender', y='Usage', hue='Product', ax=axs[0,2], palette='Set3')
sns.boxplot(data=aero, x='Gender', y='Income', hue='Product', ax=axs[1,0], palette='Set1')
sns.boxplot(data=aero, x='Gender', y='Fitness', hue='Product', ax=axs[1,1], palette='Set2')
sns.boxplot(data=aero, x='Gender', y='Miles', hue='Product', ax=axs[1,2], palette='Set3')
axs[0,0].set_title("Gender VS Age on Product ", pad=10, fontsize=14)
axs[0,1].set_title("Gender VS Education  on Product ", pad=10, fontsize=14)
axs[0,2].set_title("Gender VS Usage on Product ", pad=10, fontsize=14)
axs[1,0].set_title("Gender VS Income on Product ", pad=10, fontsize=14)
axs[1,1].set_title("Gender VS Fitness on Product ", pad=10, fontsize=14)
axs[1,2].set_title("Gender VS Miles on Product ", pad=10, fontsize=14)
# Out:
# Text(0.5, 1.0, 'Gender VS Miles on Product ')

# %% [markdown]
# Marginal Probabbailty

# %%
aero['Product'].value_counts()
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
aero['Product'].value_counts(normalize=True)
##/* With normalize set to True, returns the relative frequency by dividing all values by the sum of values ex count of KP281/sum of prod(180)
# Out:
# Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: proportion, dtype: float64

# %%
def p_prod_given_gender(gender, print_marginal=False):
    if gender != "Female" and gender != "Male":
        return "Not a valid gender value."
    
    A1 = pd.crosstab(index=aero['Gender'], columns=[aero['Product']])
    p_781 = A1['KP781'][gender] / A1.loc[gender].sum()
    p_481 = A1['KP481'][gender] / A1.loc[gender].sum()
    p_281 = A1['KP281'][gender] / A1.loc[gender].sum()
    
    if print_marginal:
        print(f"P(Male): {A1.loc['Male'].sum()/len(aero):.2f}")
        print(f"P(Female): {A1.loc['Female'].sum()/len(aero):.2f}\n")
    
    print(f"P(KP781/{gender}): {p_781:.2f}")
    print(f"P(KP481/{gender}): {p_481:.2f}")
    print(f"P(KP281/{gender}): {p_281:.2f}\n")
    
p_prod_given_gender('Male', True)
p_prod_given_gender('Female')
# Out:
# P(Male): 0.58
# P(Female): 0.42
#
# P(KP781/Male): 0.32
# P(KP481/Male): 0.30
# P(KP281/Male): 0.38
#
# P(KP781/Female): 0.09
# P(KP481/Female): 0.38
# P(KP281/Female): 0.53

# %%
def p_prod_given_gender(status, print_marginal=False):
    if status != "Single" and status != "Partnered":
        return "Invalid Status ."
    
    A2 = pd.crosstab(index=aero['MaritalStatus'], columns=[aero['Product']])
    p_781 = A2['KP781'][status] / A2.loc[status].sum()
    p_481 = A2['KP481'][status] / A2.loc[status].sum()
    p_281 = A2['KP281'][status] / A2.loc[status].sum()
    
    if print_marginal:
        print(f"P(Single): {A2.loc['Single'].sum()/len(aero):.2f}")
        print(f"P(Partnered): {A2.loc['Partnered'].sum()/len(aero):.2f}\n")
    
    print(f"P(KP781/{status}): {p_781:.2f}")
    print(f"P(KP481/{status}): {p_481:.2f}")
    print(f"P(KP281/{status}): {p_281:.2f}\n")
    
p_prod_given_gender('Single', True)
p_prod_given_gender('Partnered')
# Out:
# P(Single): 0.41
# P(Partnered): 0.59
#
# P(KP781/Single): 0.23
# P(KP481/Single): 0.33
# P(KP281/Single): 0.44
#
# P(KP781/Partnered): 0.21
# P(KP481/Partnered): 0.34
# P(KP281/Partnered): 0.45

# %% [markdown]
# Insights:
#
#
# 1.There are no missing values in the data, there are 3 unique products in the dataset,K P281 is the most frequent product.
#
#
# 2.Minimum & Maximum age of the person is 18 & 50, mean is 28.79 and 75% of persons have age less than or equal to 33.
# Most of the people are having 16 years of education i.e. 75% of persons are having education <= 16 years.
#
#
# 3.Out of 180 data points, 104's gender is Male and rest are the female.
#
#
# Univariate Analysis:
#
# 1.Age, Education and Usage are having very few outliers.
#
# 2.While Income and Miles are having more outliers.
#
# 3.People who are married are buying more than single people.
#
# 4.The KP281 is an entry-level treadmill that sells for $1,500, which is selling the most among both male and female.
#
#
# Bivariate Analysis:
#
# 1.Product vs Gender
#
#     ->Equal number of males and females have purchased KP281 product and Almost same for the product KP481
#
#     ->Most of the Male customers have purchased the KP781 product.
#
# 2.Product vs MaritalStatus
#
#     ->Customer who is Partnered, is more likely to purchase the product.
#
# 3.Product vs Age
#
#     ->Customers purchasing products KP281 & KP481 are having same Age median value.
#
#     ->Customers whose age lies between 25-30, are more likely to buy KP781 product
#
# 4.Product vs Education
#
#     ->Customers whose Education is greater than 16, have more chances to purchase the KP781 product.
#
#     ->While the customers with Education less than 16 have equal chances of purchasing KP281 or KP481.
#
# 5.Product vs Usage
#
#     ->Customers who are planning to use the treadmill greater than 4 times a week, are more likely to purchase the KP781 product.
#
#     ->While the other customers are likely to purchasing KP281 or KP481.
#
# 6.Product vs Fitness
#
#
#     ->The more the customer is fit (fitness >= 3), higher the chances of the customer to purchase the KP781 product.
#
# 7.Product vs Income
#
#     ->Higher the Income of the customer (Income >= 60000), higher the chances of the customer to purchase the KP781 product.
#
# Multivariate Analysis:
#
# 1.Females planning to use treadmill 3-4 times a week, are more likely to buy KP481 product
#
# Marginal Probability:
#
# The  probability to buy KP281 is 0.45 which is highest as per the given data since its the least expensive one.
#
# Conditional Probabilities:
#
# 1.P(KP281/Male): 0.38 probablilty of male buying KP281 is nealry 0.4 which the higest and the probablity of female buying KP281 is 0.53 which is
# more than the male. Males have 0.38 probablity of buying KP781 while females have 0.09 probablity of buying the same.
#
# 2.As seen clearly in Visual analysis above in the given data more number of paternered people are buying treadmills.
#
# 3.The probablilty of single person and patnered person buying KP281 is almost the same 0.44 & 0.45.
#
# 4.Same goes for the other 2 types of treadmills.
#
#
#
#
# Recommendations :
# 1. In the above Visual Analysis we can clearly see that the lowest end model is the most selling one too increase the sales of the other models is first too decrease the price of the KP481 and KP781.
# 2. Aerofit needs to advertise more for KP481 and KP781 and show customers these products have more features and will be better to buy these 2 types in the long run.
# 3. Offer more free maintaince and more warranty for the expensive product.
# 4. Take surveys and based on the usage and income reccomend them higher end types.
# 5. Target more single people and young people in advertising since they are likely too spend more.
# 6. Partenered people might have higer the usage than single people saying  for more duarablility offer them deals on higher end types which might entice them to buy KP481 or KP781.
